# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd

# %%
# Load the 7259deaf70e0b097.xlsx file and drop unnecessary columns
AAPL_option = pd.read_excel('/Users/baronma/Desktop/7259deaf70e0b097.xlsx')

# %%
AAPL_option.head()
# Out:
#    Security ID  The Date of this Price       Option Symbol  \
# 0       101594                20120904  AAPL 120907C590000
# 1       101594                20120904  AAPL 120907C595000
# 2       101594                20120904  AAPL 120907C600000
# 3       101594                20120904  AAPL 120907C605000
# 4       101594                20120904  AAPL 120907C610000
#
#    Expiration Date of the Option C=Call, P=Put  \
# 0                       20120907             C
# 1                       20120907             C
# 2                       20120907             C
# 3                       20120907             C
# 4                       20120907             C
#
#    Strike Price of the Option Times 1000  \
# 0                                 590000
# 1                                 595000
# 2                                 600000
# 3                                 605000
# 4                                 610000
#
#    Highest Closing Bid Across All Exchanges  \
# 0                                     84.70
# 1                                     78.90
# 2                                     74.70
# 3                                     68.85
# 4                                     64.75
#
#    Lowest  Closing Ask Across All Exchanges  Open Interest for the Option  \
# 0                                     85.50                           113
# 1                                     80.80                             0
# 2                                     75.15                            40
# 3                                     70.70                             0
# 4                                     65.45                             8
#
#    Implied Volatility of the Option  Unique ID for the Option Contract  \
# 0                          0.636391                           83202292
# 1                               NaN                           83202293
# 2                               NaN                           83202294
# 3                               NaN                           83202295
# 4                          0.495483                           83202296
#
#   Ticker Symbol  Index Flag Description of the Issuing Company  \
# 0          AAPL           0                          APPLE INC
# 1          AAPL           0                          APPLE INC
# 2          AAPL           0                          APPLE INC
# 3          AAPL           0                          APPLE INC
# 4          AAPL           0                          APPLE INC
#
#   (A)merican, (E)uropean, or ?
# 0                            A
# 1                            A
# 2                            A
# 3                            A
# 4                            A

# %%
AAPL_option.drop(['Security ID', 'Option Symbol', 'Unique ID for the Option Contract', 'Ticker Symbol', 'Index Flag',
                  'Description of the Issuing Company', '(A)merican, (E)uropean, or ?','Highest Closing Bid Across All Exchanges'], axis = 1, inplace = True)

# %%
# Load the Stock Prices.xlsx file and filter AAPL stock ptice.
AAPL_stock = pd.read_excel('/Users/baronma/Desktop/Stock Prices.xlsx')
AAPL_stock = AAPL_stock[AAPL_stock['Ticker Symbol'] == 'AAPL']

# %%
# Rename the 'The Date for this Price Record' column to be the same as the AAPL option dataframe, in order to merge these two.
AAPL_stock.rename(columns = {'The Date for this Price Record': 'The Date of this Price'}, inplace = True)
AAPL_stock.head()
# Out:
#       Security ID  The Date of this Price Ticker Symbol  \
# 1340       101594                20120904          AAPL
# 1341       101594                20120905          AAPL
# 1342       101594                20120906          AAPL
# 1343       101594                20120907          AAPL
# 1344       101594                20120910          AAPL
#
#       Close (or Bid-Ask Average if Negative)  Cumulative Adjustment Factor
# 1340                                  674.97                             4
# 1341                                  670.23                             4
# 1342                                  676.27                             4
# 1343                                  680.44                             4
# 1344                                  662.74                             4

# %%
# Get the original strike price
AAPL_option['Strike Price of the Option Times 1000'] = AAPL_option['Strike Price of the Option Times 1000'].apply(lambda x: x/1000)
AAPL_option.rename(columns={'Strike Price of the Option Times 1000': 'Strike Price'}, inplace=True)

# %%
# Left join AAPL_stock to AAPL_option in order to add the underlying stock price to the option
AAPL = pd.merge(AAPL_option, AAPL_stock, on = ['The Date of this Price'], how = 'left')

# %%
AAPL.drop(['Security ID', 'Ticker Symbol', 'Cumulative Adjustment Factor'], axis = 1, inplace = True)
AAPL.rename(columns = {'Close (or Bid-Ask Average if Negative)' : 'Underlying Price'}, inplace = True)

# %%
AAPL.head()
# Out:
#    The Date of this Price  Expiration Date of the Option C=Call, P=Put  \
# 0                20120904                       20120907             C
# 1                20120904                       20120907             C
# 2                20120904                       20120907             C
# 3                20120904                       20120907             C
# 4                20120904                       20120907             C
#
#    Strike Price  Lowest  Closing Ask Across All Exchanges  \
# 0         590.0                                     85.50
# 1         595.0                                     80.80
# 2         600.0                                     75.15
# 3         605.0                                     70.70
# 4         610.0                                     65.45
#
#    Open Interest for the Option  Implied Volatility of the Option  \
# 0                           113                          0.636391
# 1                             0                               NaN
# 2                            40                               NaN
# 3                             0                               NaN
# 4                             8                          0.495483
#
#    Underlying Price
# 0            674.97
# 1            674.97
# 2            674.97
# 3            674.97
# 4            674.97

# %%
# Change the text date to the standard date format
AAPL['The Date of this Price'] = pd.to_datetime(AAPL['The Date of this Price'], format = '%Y%m%d')
AAPL['Expiration Date of the Option'] = pd.to_datetime(AAPL['Expiration Date of the Option'], format = '%Y%m%d')

# %%
# Calculate the maturity days
AAPL['maturity'] = (AAPL['Expiration Date of the Option'] - AAPL['The Date of this Price']).dt.days

# %%
AAPL_withoutNaN = AAPL[AAPL['Implied Volatility of the Option'].notnull()]
len(AAPL_withoutNaN)
# Out:
# 727050

# %%
# One hot encoding to the 'C=Call, P=Put' column
AAPL_final = pd.get_dummies(data=AAPL, columns=['C=Call, P=Put'])
AAPL_final_2 = pd.get_dummies(data=AAPL_withoutNaN, columns=['C=Call, P=Put'])

# %%
AAPL_final.head()
# Out:
#   The Date of this Price Expiration Date of the Option  Strike Price  \
# 0             2012-09-04                    2012-09-07         590.0
# 1             2012-09-04                    2012-09-07         595.0
# 2             2012-09-04                    2012-09-07         600.0
# 3             2012-09-04                    2012-09-07         605.0
# 4             2012-09-04                    2012-09-07         610.0
#
#    Lowest  Closing Ask Across All Exchanges  Open Interest for the Option  \
# 0                                     85.50                           113
# 1                                     80.80                             0
# 2                                     75.15                            40
# 3                                     70.70                             0
# 4                                     65.45                             8
#
#    Implied Volatility of the Option  Underlying Price  maturity  \
# 0                          0.636391            674.97         3
# 1                               NaN            674.97         3
# 2                               NaN            674.97         3
# 3                               NaN            674.97         3
# 4                          0.495483            674.97         3
#
#    C=Call, P=Put_C  C=Call, P=Put_P
# 0                1                0
# 1                1                0
# 2                1                0
# 3                1                0
# 4                1                0

# %%
AAPL_final.to_csv('Cleaned.csv')

# %%
AAPL_final_2.to_csv('Cleaned_withoutNaN.csv')
